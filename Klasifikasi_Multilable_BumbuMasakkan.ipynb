# %% [markdown]
# <a href="https://colab.research.google.com/github/Anisafi/T3-deeplearning/blob/main/Klasifikasi_Multilable_BumbuMasakkan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.preprocessing import image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from keras.layers import BatchNormalization

# %%
#image_directory = 'DatasetMultilable_AnisahFitriani_202255202069/DatasetMultilable_AnisahFitriani_202255202069/'

#import kagglehub

# Download latest version
#path = kagglehub.dataset_download("anisahfitriani/dataset-multilable-bumbu-masakkan")

#print("Path to dataset files:", path)

# %%
import os
os.environ["KAGGLE_USERNAME"] = "anisahfitriani" # Ganti dengan username Kaggle Anda
os.environ["KAGGLE_KEY"] = "72d6c6a3cc093cf7c22558c6a7f29ebd" # Ganti dengan key yang ada di kaggle.json

# %%
# !kaggle datasets download -d anisahfitriani/dataset-multilable-bumbu-masakkan
# Out:
# Dataset URL: https://www.kaggle.com/datasets/anisahfitriani/dataset-multilable-bumbu-masakkan
# License(s): CC0-1.0
# Downloading dataset-multilable-bumbu-masakkan.zip to /content
#  86% 324M/376M [00:02<00:00, 84.6MB/s]
# 100% 376M/376M [00:02<00:00, 133MB/s]

# %%
# prompt: unzip file dataset-multilable-bumbu-masakkan.zip

# !unzip dataset-multilable-bumbu-masakkan.zip
# Out:
# Archive:  dataset-multilable-bumbu-masakkan.zip
#   inflating: DatasetMultilable_AnisahFitriani_202255202069.csv
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255001.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255002.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255003.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255004.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255005.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255006.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255007.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255008.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255009.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255010.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255011.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255012.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255013.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255014.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255015.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255016.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255017.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255018.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255019.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255020.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255021.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255022.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255023.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255024.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255025.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255026.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255027.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255028.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255029.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255030.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255031.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255032.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255033.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255034.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255035.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255036.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255037.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255038.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255039.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255040.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255041.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255042.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255043.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255044.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255045.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255046.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255047.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255048.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255049.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255050.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255051.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255052.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255053.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255054.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255055.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255056.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255057.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255058.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255059.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255060.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255061.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255062.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255063.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255064.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255065.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255066.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255067.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255068.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255069.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255070.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255071.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255072.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255073.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255074.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255075.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255076.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255077.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255078.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255079.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255080.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255081.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255082.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255083.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255084.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255085.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255086.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255087.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255088.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255089.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255090.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255091.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255092.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255093.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255094.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255095.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255096.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255097.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255098.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255099.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255100.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255101.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255102.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255103.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255104.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255105.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255106.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255107.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255108.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255109.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255110.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255111.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255112.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255113.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255114.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255115.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255116.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255117.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255118.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255119.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255120.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255121.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255122.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255123.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255124.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255125.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255126.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255127.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255128.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255129.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255130.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255131.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255132.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255133.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255134.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255135.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255136.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255137.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255138.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255139.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255140.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255141.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255142.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255143.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255144.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255145.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255146.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255147.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255148.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255149.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255150.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255151.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255152.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255153.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255154.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255155.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255156.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255157.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255158.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255159.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255160.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255161.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255162.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255163.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255164.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255165.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255166.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255167.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255168.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255169.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255170.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255171.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255172.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255173.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255174.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255175.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255176.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255177.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255178.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255179.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255180.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255181.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255182.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255183.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255184.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255185.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255186.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255187.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255188.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255189.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255190.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255191.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255192.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255193.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255194.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255195.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255196.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255197.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255198.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255199.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255200.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255201.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255202.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255203.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255204.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255205.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255206.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255207.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255208.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255209.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255210.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255211.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255212.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255213.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255214.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255215.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255216.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255217.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255218.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255219.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255220.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255221.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255222.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255223.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255224.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255225.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255226.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255227.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255228.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255229.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255230.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255231.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255232.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255233.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255234.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255235.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255236.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255237.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255238.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255239.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255240.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255241.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255242.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255243.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255244.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255245.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255246.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255247.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255248.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255249.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255250.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255251.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255252.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255253.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255254.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255255.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255256.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255257.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255258.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255259.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255260.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255261.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255262.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255263.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255264.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255265.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255266.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255267.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255268.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255269.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255270.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255271.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255272.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255273.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255274.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255275.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255276.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255277.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255278.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255279.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255280.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255281.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255282.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255283.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255284.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255285.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255286.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255287.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255288.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255289.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255290.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255291.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255292.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255293.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255294.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255295.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255296.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255297.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255298.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255299.jpg
#   inflating: DatasetMultilable_AnisahFitriani_202255202069/An202255300.jpg

# %%
#Now let us read metadata to get our Y values (multiple lables)
# Try reading with semicolon as delimiter
try:
    df = pd.read_csv('/content/DatasetMultilable_AnisahFitriani_202255202069.csv', sep=';')
    print("Read with semicolon delimiter successful.")
except pd.errors.ParserError: # Changed to pd.errors.ParserError for clarity
    print("Reading with semicolon delimiter failed. Trying default comma delimiter (might still fail).")
    df = pd.read_csv('/content/DatasetMultilable_AnisahFitriani_202255202069.csv')

print(df.head())     # printing first five rows of the file
print(df.columns)

df = df.iloc[:2000].reset_index(drop=True)  #Loading only first 2000 datapoints and reset the index
#Need to read images using the tag from metadata.
#Otherwise, if read directly from the folder then images may not correspond to
#the metadata from the csv file.
# Out:
# Read with semicolon delimiter successful.
#             id jenis bumbu masakkan  tomat  bawang merah  bawang putih  jeruk  \
# 0  An202255001          tomat,jeruk      1             0             0      1
# 1  An202255002   bawang putih,jeruk      0             0             1      1
# 2  An202255003         kemiri,jeruk      0             0             0      1
# 3  An202255004         kemiri,jeruk      0             0             0      1
# 4  An202255005         tomat,kemiri      1             0             0      0
#
#    kemiri
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
# Index(['id', 'jenis bumbu masakkan', 'tomat', 'bawang merah', 'bawang putih',
#        'jeruk', 'kemiri'],
#       dtype='object')

# %%
SIZE = 200
X_dataset = []
#Define image_directory before it's used in the loop
image_directory = '/content/DatasetMultilable_AnisahFitriani_202255202069' # Change to extracted image directory

# Print the column names to verify the correct identifier column
print(df.columns)

for i in tqdm(range(df.shape[0])):
    # Replace 'Id' with the actual column name for the image identifiers found from the print statement above
    # Added '/' as a separator between image_directory and filename
    # Changed 'YOUR_CORRECT_ID_COLUMN_NAME' to the actual column name 'id'
    img = image.load_img(image_directory + '/' + df['id'][i]+'.jpg', target_size=(SIZE,SIZE,3))
    img = image.img_to_array(img)
    img = img/255.
    X_dataset.append(img)

X = np.array(X_dataset)
# Out:
# Index(['id', 'jenis bumbu masakkan', 'tomat', 'bawang merah', 'bawang putih',
#        'jeruk', 'kemiri'],
#       dtype='object')
# 100%|██████████| 300/300 [00:13<00:00, 22.38it/s]

# %%
#
print(df['id'][7])  #King Kong
# Out:
# An202255008

# %%
print(df['jenis bumbu masakkan'][7])  #Tagged as multiple Genres.
# Out:
# bawang merah,bawang putih

# %%
#Id and Genre are not labels to be trained. So drop them from the dataframe.
#No need to convert to categorical as the dataset is already in the right format.
y = np.array(df.drop(['id', 'jenis bumbu masakkan'], axis=1))

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=20, test_size=0.3)

# %%
model = Sequential()

model.add(Conv2D(filters=16, kernel_size=(5, 5), activation="relu", input_shape=(SIZE,SIZE,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=(5, 5), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(5, activation='sigmoid'))

#Do not use softmax for multilabel classification
#Softmax is useful for mutually exclusive classes, either cat or dog but not both.
#Also, softmax outputs all add to 1. So good for multi class problems where each
#class is given a probability and all add to 1. Highest one wins.

#Sigmoid outputs probability. Can be used for non-mutually exclusive problems.
#like multi label, in this example.
#But, also good for binary mutually exclusive (cat or not cat).

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 196, 196, 16)   │         1,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 196, 196, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 98, 98, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 98, 98, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 94, 94, 32)     │        12,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 47, 47, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 47, 47, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 47, 47, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 43, 43, 64)     │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 21, 21, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 21, 21, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 21, 21, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 17, 17, 64)     │       102,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 8, 8, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       524,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 701,477 (2.68 MB)
#  Trainable params: 701,125 (2.67 MB)
#  Non-trainable params: 352 (1.38 KB)

# %%
#Binary cross entropy of each label. So no really a binary classification problem but
#Calculating binary cross entropy for each label.
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=200, validation_data=(X_test, y_test), batch_size=32)
# Out:
# Epoch 1/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 25s 2s/step - accuracy: 0.1797 - loss: 1.0221 - val_accuracy: 0.2889 - val_loss: 0.6825
# Epoch 2/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 20s 71ms/step - accuracy: 0.2253 - loss: 0.9033 - val_accuracy: 0.0111 - val_loss: 0.6810
# Epoch 3/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.2531 - loss: 0.7494 - val_accuracy: 0.0667 - val_loss: 0.6855
# Epoch 4/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.3242 - loss: 0.7970 - val_accuracy: 0.1000 - val_loss: 0.7145
# Epoch 5/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.2790 - loss: 0.7231 - val_accuracy: 0.1000 - val_loss: 0.7772
# Epoch 6/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2868 - loss: 0.6399 - val_accuracy: 0.1000 - val_loss: 0.9076
# Epoch 7/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2802 - loss: 0.6152 - val_accuracy: 0.1000 - val_loss: 1.0223
# Epoch 8/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.2113 - loss: 0.6363 - val_accuracy: 0.1000 - val_loss: 1.0950
# Epoch 9/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3237 - loss: 0.5682 - val_accuracy: 0.1000 - val_loss: 1.1703
# Epoch 10/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.3189 - loss: 0.6087 - val_accuracy: 0.1000 - val_loss: 1.1902
# Epoch 11/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.3144 - loss: 0.5812 - val_accuracy: 0.1000 - val_loss: 1.2612
# Epoch 12/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.2256 - loss: 0.5213 - val_accuracy: 0.1000 - val_loss: 1.3922
# Epoch 13/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.3175 - loss: 0.6049 - val_accuracy: 0.1000 - val_loss: 1.4383
# Epoch 14/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3286 - loss: 0.5275 - val_accuracy: 0.1000 - val_loss: 1.4182
# Epoch 15/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.3123 - loss: 0.5612 - val_accuracy: 0.1000 - val_loss: 1.4229
# Epoch 16/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3982 - loss: 0.5534 - val_accuracy: 0.1000 - val_loss: 1.4722
# Epoch 17/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.3152 - loss: 0.5058 - val_accuracy: 0.1000 - val_loss: 1.4824
# Epoch 18/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.3327 - loss: 0.5076 - val_accuracy: 0.1000 - val_loss: 1.4949
# Epoch 19/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.3278 - loss: 0.4810 - val_accuracy: 0.1000 - val_loss: 1.5618
# Epoch 20/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.2496 - loss: 0.4818 - val_accuracy: 0.1000 - val_loss: 1.5507
# Epoch 21/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.3480 - loss: 0.4935 - val_accuracy: 0.1000 - val_loss: 1.5670
# Epoch 22/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.3630 - loss: 0.4673 - val_accuracy: 0.1000 - val_loss: 1.5580
# Epoch 23/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.2965 - loss: 0.4489 - val_accuracy: 0.1000 - val_loss: 1.5399
# Epoch 24/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.2843 - loss: 0.4532 - val_accuracy: 0.1000 - val_loss: 1.6006
# Epoch 25/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.3105 - loss: 0.4534 - val_accuracy: 0.1000 - val_loss: 1.4757
# Epoch 26/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.3709 - loss: 0.4345 - val_accuracy: 0.1000 - val_loss: 1.4287
# Epoch 27/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.3309 - loss: 0.4890 - val_accuracy: 0.1000 - val_loss: 1.3913
# Epoch 28/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.3567 - loss: 0.4534 - val_accuracy: 0.1000 - val_loss: 1.4744
# Epoch 29/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.3725 - loss: 0.4025 - val_accuracy: 0.1000 - val_loss: 1.6478
# Epoch 30/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4071 - loss: 0.4051 - val_accuracy: 0.1000 - val_loss: 1.7301
# Epoch 31/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.3133 - loss: 0.4344 - val_accuracy: 0.1000 - val_loss: 1.7388
# Epoch 32/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.
# Epoch 192/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5589 - loss: 0.0842 - val_accuracy: 0.3556 - val_loss: 0.7259
# Epoch 193/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.4861 - loss: 0.0798 - val_accuracy: 0.3111 - val_loss: 0.6933
# Epoch 194/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.4278 - loss: 0.0942 - val_accuracy: 0.3444 - val_loss: 0.6694
# Epoch 195/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5002 - loss: 0.0816 - val_accuracy: 0.3222 - val_loss: 0.6507
# Epoch 196/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5435 - loss: 0.0639 - val_accuracy: 0.3333 - val_loss: 0.6653
# Epoch 197/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5483 - loss: 0.0683 - val_accuracy: 0.4333 - val_loss: 0.6853
# Epoch 198/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.5259 - loss: 0.1434 - val_accuracy: 0.4667 - val_loss: 0.6822
# Epoch 199/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5433 - loss: 0.1071 - val_accuracy: 0.4333 - val_loss: 0.6711
# Epoch 200/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5255 - loss: 0.0830 - val_accuracy: 0.4222 - val_loss: 0.6900

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %%
#Validate on an image
#img = image.load_img('/content/Multi_Label_dataset/Images/tt0085318.jpg', target_size=(SIZE,SIZE,3))
# Assuming 'ddlj.jpg' is in '/content/Multi_Label_dataset/Images/'
img = image.load_img('/content/DatasetMultilable_AnisahFitriani_202255202069/An202255007.jpg', target_size=(SIZE,SIZE,3))

img = image.img_to_array(img)
img = img/255.
plt.imshow(img)
img = np.expand_dims(img, axis=0)

classes = np.array(df.columns[2:]) #Get array of all classes
proba = model.predict(img)  #Get probabilities for each class
sorted_categories = np.argsort(proba[0])[:-11:-1]  #Get class names for top 10 categories
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 828ms/step

# %%
#Print classes and corresponding probabilities
# Iterate up to the number of available classes
for i in range(len(classes)):
    # Access elements using the sorted indices
    print("{}".format(classes[sorted_categories[i]])+" ({:.3})".format(proba[0][sorted_categories[i]]))
# Out:
# jeruk (0.995)
# bawang merah (0.984)
# bawang putih (0.0123)
# kemiri (0.00663)
# tomat (0.00289)

# %%
###################################################

_, acc = model.evaluate(X_test, y_test)
print("Accuracy = ", (acc * 100.0), "%")

################################################################
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4299 - loss: 0.7382
# Accuracy =  42.222222685813904 %

# %%
# prompt: berikan code evaluasi model

from sklearn.metrics import classification_report, confusion_matrix

# Make predictions on the test set
y_pred = model.predict(X_test)

# Convert probabilities to class labels (e.g., using a threshold)
y_pred_classes = (y_pred > 0.5).astype(int)  # Assuming 0.5 as the threshold

# Calculate and print the classification report
print(classification_report(y_test, y_pred_classes, target_names=classes))


# Calculate and print the confusion matrix (optional)
# Note: Confusion matrices are best visualized for binary or few-class problems
# For multi-label, confusion matrix for each label is more informative
for i in range(len(classes)):
  print(f"Confusion Matrix for {classes[i]}:")
  print(confusion_matrix(y_test[:,i], y_pred_classes[:,i]))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 188ms/step
#               precision    recall  f1-score   support
#
#        tomat       0.98      0.88      0.93        50
# bawang merah       0.79      0.83      0.81        64
# bawang putih       0.65      0.90      0.76        50
#        jeruk       0.89      0.75      0.82        53
#       kemiri       0.76      0.89      0.82        53
#
#    micro avg       0.80      0.85      0.82       270
#    macro avg       0.81      0.85      0.83       270
# weighted avg       0.81      0.85      0.82       270
#  samples avg       0.77      0.83      0.79       270
#
# Confusion Matrix for tomat:
# [[39  1]
#  [ 6 44]]
# Confusion Matrix for bawang merah:
# [[12 14]
#  [11 53]]
# Confusion Matrix for bawang putih:
# [[16 24]
#  [ 5 45]]
# Confusion Matrix for jeruk:
# [[32  5]
#  [13 40]]
# Confusion Matrix for kemiri:
# [[22 15]
#  [ 6 47]]
